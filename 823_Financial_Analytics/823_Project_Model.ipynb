# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns 

import itertools

import scipy

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv(r"C:\Users\lu_xi\OneDrive\Queens MMA\823 Analytics for Financial Markets\Course Project\Data\clean_data.csv")
# df_train = pd.read_csv(r"C:\Users\lu_xi\OneDrive\Queens MMA\823 Analytics for Financial Markets\Course Project\Data\new_train.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32950 entries, 0 to 32949
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    32950 non-null  int64
#  1   age           32950 non-null  object
#  2   job           32950 non-null  object
#  3   marital       32950 non-null  object
#  4   education     32950 non-null  object
#  5   default       32950 non-null  object
#  6   housing       32950 non-null  object
#  7   loan          32950 non-null  object
#  8   contact       32950 non-null  object
#  9   month         32950 non-null  object
#  10  duration      32950 non-null  float64
#  11  campaign      32950 non-null  int64
#  12  previous      32950 non-null  int64
#  13  poutcome      32950 non-null  object
#  14  y             32950 non-null  int64
#  15  duration_min  32950 non-null  float64
#  16  campaign1     32950 non-null  bool
#  17  student       32950 non-null  bool
#  18  retired       32950 non-null  bool
# dtypes: bool(3), float64(2), int64(4), object(10)
# memory usage: 4.1+ MB

# %%
df.head(3)
# Out:
#    Unnamed: 0    age           job  marital          education  default  \
# 0           1  41-50   blue-collar  married           basic.9y  unknown
# 1           2  31-40  entrepreneur  married  university.degree       no
# 2           3    >60       retired  married           basic.4y       no
#
#   housing loan    contact month  duration  campaign  previous     poutcome  y  \
# 0      no   no   cellular    Q4  1.565138         4         0  nonexistent  0
# 1      no   no  telephone    Q4  1.474000         2         1      failure  0
# 2      no   no   cellular    Q3  3.002377         1         0  nonexistent  1
#
#    duration_min  campaign1  student  retired
# 0      3.783333      False    False    False
# 1      3.366667      False    False    False
# 2     19.133333       True    False     True

# %%
from sklearn.model_selection import train_test_split

X = df.drop(['y'], axis=1)
y = df['y']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=7)

# %%
y_train.value_counts()
y_test.value_counts()
# Out:
# 0    23390
# 1     2970
# Name: y, dtype: int64
# 0    5848
# 1     742
# Name: y, dtype: int64

# %%
from pycaret.classification import *

# %%
#intialize the setup
exp_clf = setup(df, target = 'y', session_id = 123)
# Out:
# <style type="text/css">
# #T_7e7cc_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7e7cc_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e7cc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e7cc_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_7e7cc_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e7cc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_7e7cc_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7e7cc_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_7e7cc_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7e7cc_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_7e7cc_row3_col1" class="data row3 col1" >0: 0, 1: 1</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7e7cc_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_7e7cc_row4_col1" class="data row4 col1" >(32950, 19)</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7e7cc_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_7e7cc_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7e7cc_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_7e7cc_row6_col1" class="data row6 col1" >4</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7e7cc_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_7e7cc_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7e7cc_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_7e7cc_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7e7cc_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_7e7cc_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_7e7cc_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_7e7cc_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_7e7cc_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_7e7cc_row11_col1" class="data row11 col1" >(23064, 54)</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_7e7cc_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_7e7cc_row12_col1" class="data row12 col1" >(9886, 54)</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_7e7cc_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_7e7cc_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_7e7cc_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_7e7cc_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_7e7cc_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_7e7cc_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_7e7cc_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_7e7cc_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_7e7cc_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_7e7cc_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_7e7cc_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_7e7cc_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_7e7cc_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_7e7cc_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_7e7cc_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_7e7cc_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_7e7cc_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_7e7cc_row21_col1" class="data row21 col1" >6847</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_7e7cc_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_7e7cc_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_7e7cc_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_7e7cc_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_7e7cc_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_7e7cc_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_7e7cc_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_7e7cc_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_7e7cc_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_7e7cc_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_7e7cc_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_7e7cc_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_7e7cc_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_7e7cc_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_7e7cc_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_7e7cc_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_7e7cc_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_7e7cc_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_7e7cc_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <tr

# %%
best_model = compare_models()
# Out:
# <style type="text/css">
# #T_860de_ th {
#   text-align: left;
# }
# #T_860de_row0_col0, #T_860de_row0_col2, #T_860de_row0_col3, #T_860de_row0_col4, #T_860de_row0_col5, #T_860de_row0_col6, #T_860de_row1_col0, #T_860de_row1_col1, #T_860de_row1_col2, #T_860de_row1_col3, #T_860de_row1_col4, #T_860de_row1_col5, #T_860de_row1_col6, #T_860de_row1_col7, #T_860de_row2_col0, #T_860de_row2_col1, #T_860de_row2_col3, #T_860de_row2_col4, #T_860de_row2_col5, #T_860de_row2_col6, #T_860de_row2_col7, #T_860de_row3_col0, #T_860de_row3_col1, #T_860de_row3_col2, #T_860de_row3_col3, #T_860de_row3_col4, #T_860de_row3_col7, #T_860de_row4_col0, #T_860de_row4_col1, #T_860de_row4_col2, #T_860de_row4_col3, #T_860de_row4_col4, #T_860de_row4_col5, #T_860de_row4_col6, #T_860de_row4_col7, #T_860de_row5_col0, #T_860de_row5_col1, #T_860de_row5_col2, #T_860de_row5_col3, #T_860de_row5_col4, #T_860de_row5_col5, #T_860de_row5_col6, #T_860de_row5_col7, #T_860de_row6_col0, #T_860de_row6_col1, #T_860de_row6_col2, #T_860de_row6_col3, #T_860de_row6_col5, #T_860de_row6_col6, #T_860de_row6_col7, #T_860de_row7_col0, #T_860de_row7_col1, #T_860de_row7_col2, #T_860de_row7_col3, #T_860de_row7_col4, #T_860de_row7_col5, #T_860de_row7_col6, #T_860de_row7_col7, #T_860de_row8_col0, #T_860de_row8_col1, #T_860de_row8_col2, #T_860de_row8_col3, #T_860de_row8_col4, #T_860de_row8_col5, #T_860de_row8_col6, #T_860de_row8_col7, #T_860de_row9_col0, #T_860de_row9_col1, #T_860de_row9_col2, #T_860de_row9_col3, #T_860de_row9_col4, #T_860de_row9_col5, #T_860de_row9_col6, #T_860de_row9_col7, #T_860de_row10_col0, #T_860de_row10_col1, #T_860de_row10_col2, #T_860de_row10_col3, #T_860de_row10_col4, #T_860de_row10_col5, #T_860de_row10_col6, #T_860de_row10_col7, #T_860de_row11_col0, #T_860de_row11_col1, #T_860de_row11_col2, #T_860de_row11_col3, #T_860de_row11_col4, #T_860de_row11_col5, #T_860de_row11_col6, #T_860de_row11_col7, #T_860de_row12_col0, #T_860de_row12_col1, #T_860de_row12_col2, #T_860de_row12_col3, #T_860de_row12_col4, #T_860de_row12_col5, #T_860de_row12_col6, #T_860de_row12_col7, #T_860de_row13_col0, #T_860de_row13_col1, #T_860de_row13_col2, #T_860de_row13_col4, #T_860de_row13_col5, #T_860de_row13_col6, #T_860de_row13_col7, #T_860de_row14_col0, #T_860de_row14_col1, #T_860de_row14_col2, #T_860de_row14_col3, #T_860de_row14_col4, #T_860de_row14_col5, #T_860de_row14_col6, #T_860de_row14_col7 {
#   text-align: left;
# }
# #T_860de_row0_col1, #T_860de_row0_col7, #T_860de_row2_col2, #T_860de_row3_col5, #T_860de_row3_col6, #T_860de_row6_col4, #T_860de_row13_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_860de_row0_col8, #T_860de_row1_col8, #T_860de_row2_col8, #T_860de_row3_col8, #T_860de_row4_col8, #T_860de_row5_col8, #T_860de_row6_col8, #T_860de_row7_col8, #T_860de_row8_col8, #T_860de_row9_col8, #T_860de_row10_col8, #T_860de_row11_col8, #T_860de_row12_col8, #T_860de_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_860de_row14_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_860de_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_860de_level0_row0" class="row_heading level0 row0" >gbc</th>
#       <td id="T_860de_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_860de_row0_col1" class="data row0 col1" >0.9086</td>
#       <td id="T_860de_row0_col2" class="data row0 col2" >0.9134</td>
#       <td id="T_860de_row0_col3" class="data row0 col3" >0.4090</td>
#       <td id="T_860de_row0_col4" class="data row0 col4" >0.6419</td>
#       <td id="T_860de_row0_col5" class="data row0 col5" >0.4993</td>
#       <td id="T_860de_row0_col6" class="data row0 col6" >0.4518</td>
#       <td id="T_860de_row0_col7" class="data row0 col7" >0.4659</td>
#       <td id="T_860de_row0_col8" class="data row0 col8" >2.3530</td>
#     </tr>
#     <tr>
#       <th id="T_860de_level0_row1" class="row_heading level0 row1" >lr</th>
#       <td id="T_860de_row1_col0" class="data row1 col0" >Logistic Regression</td>
#       <td id="T_860de_row1_col1" class="data row1 col1" >0.9079</td>
#       <td id="T_860de_row1_col2" class="data row1 col2" >0.9040</td>
#       <td id="T_860de_row1_col3" class="data row1 col3" >0.3624</td>
#       <td id="T_860de_row1_col4" class="data row1 col4" >0.6583</td>
#       <td id="T_860de_row1_col5" class="data row1 col5" >0.4664</td>
#       <td id="T_860de_row1_col6" class="data row1 col6" >0.4207</td>
#       <td id="T_860de_row1_col7" class="data row1 col7" >0.4437</td>
#       <td id="T_860de_row1_col8" class="data row1 col8" >1.9150</td>
#     </tr>
#     <tr>
#       <th id="T_860de_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_860de_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_860de_row2_col1" class="data row2 col1" >0.9062</td>
#       <td id="T_860de_row2_col2" class="data row2 col2" >0.9152</td>
#       <td id="T_860de_row2_col3" class="data row2 col3" >0.4063</td>
#       <td id="T_860de_row2_col4" class="data row2 col4" >0.6213</td>
#       <td id="T_860de_row2_col5" class="data row2 col5" >0.4906</td>
#       <td id="T_860de_row2_col6" class="data row2 col6" >0.4416</td>
#       <td id="T_860de_row2_col7" class="data row2 col7" >0.4540</td>
#       <td id="T_860de_row2_col8" class="data row2 col8" >0.4560</td>
#     </tr>
#     <tr>
#       <th id="T_860de_level0_row3" class="row_heading level0 row3" >lda</th>
#       <td id="T_860de_row3_col0" class="data row3 col0" >Linear Discriminant Analysis</td>
#       <td id="T_860de_row3_col1" class="data row3 col1" >0.9051</td>
#       <td id="T_860de_row3_col2" class="data row3 col2" >0.9025</td>
#       <td id="T_860de_row3_col3" class="data row3 col3" >0.4374</td>
#       <td id="T_860de_row3_col4" class="data row3 col4" >0.6031</td>
#       <td id="T_860de_row3_col5" class="data row3 col5" >0.5063</td>
#       <td id="T_860de_row3_col6" class="data row3 col6" >0.4554</td>
#       <td id="T_860de_row3_col7" class="data row3 col7" >0.4630</td>
#       <td id="T_860de_row3_col8" class="data row3 col8" >0.2470</td>
#     </tr>
#     <tr>
#       <th id="T_860de_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_860de_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_860de_row4_col1" class="data row4 col1" >0.9050</td>
#       <td id="T_860de_row4_col2" class="data row4 col2" >0.9039</td>
#       <td id="T_860de_row4_col3" class="data row4 col3" >0.3880</td>
#       <td id="T_860de_row4_col4" class="data row4 col4" >0.6190</td>
#       <td id="T_860de_row4_col5" class="data row4 col5" >0.4764</td>
#       <td id="T_860de_row4_col6" class="data row4 col6" >0.4273</td>
#       <td id="T_860de_row4_col7" class="data row4 col7" >0.4417</td>
#       <td id="T_860de_row4_col8" class="data row4 col8" >0.6930</td>
#     </tr>
#     <tr>
#       <th id="T_860de_level0_row5" class="row_heading level0 row5" >catboost</th>
#       <td id="T_860de_row5_col0" class="data row5 col0" >CatBoost Classifier</td>
#       <td id="T_860de_row5_col1" class="data row5 col1" >0.9041</td>
#       <td id="T_860de_row5_col2" class="data row5 col2" >0.9147</td>
#       <td id="T_860de_row5_col3" class="data row5 col3" >0.4055</td>
#       <td id="T_860de_row5_col4" class="data row5 col4" >0.6041</td>
#       <td id="T_860de_row5_col5" class="data row5 col5" >0.4849</td>
#       <td id="T_860de_row5_col6" class="data row5 col6" >0.4343</td>
#       <td id="T_860de_row5_col7" class="data row5 col7" >0.4450</td>
#       <td id="T_860de_row5_col8"

# %%
print(best_model)
# Out:
# GradientBoostingClassifier(ccp_alpha=0.0, criterion='friedman_mse', init=None,
#                            learning_rate=0.1, loss='deviance', max_depth=3,
#                            max_features=None, max_leaf_nodes=None,
#                            min_impurity_decrease=0.0, min_impurity_split=None,
#                            min_samples_leaf=1, min_samples_split=2,
#                            min_weight_fraction_leaf=0.0, n_estimators=100,
#                            n_iter_no_change=None, presort='deprecated',
#                            random_state=123, subsample=1.0, tol=0.0001,
#                            validation_fraction=0.1, verbose=0,
#                            warm_start=False)

# %%
predict_model(best_model);
# Out:
# <style type="text/css">
# </style>
# <table id="T_72db9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72db9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72db9_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_72db9_row0_col1" class="data row0 col1" >0.9055</td>
#       <td id="T_72db9_row0_col2" class="data row0 col2" >0.9170</td>
#       <td id="T_72db9_row0_col3" class="data row0 col3" >0.3921</td>
#       <td id="T_72db9_row0_col4" class="data row0 col4" >0.6497</td>
#       <td id="T_72db9_row0_col5" class="data row0 col5" >0.4891</td>
#       <td id="T_72db9_row0_col6" class="data row0 col6" >0.4405</td>
#       <td id="T_72db9_row0_col7" class="data row0 col7" >0.4576</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_model = finalize_model(best_model)

# %% [markdown]
# FLAML Try-out

# %%
# ! pip install flaml

# %%
# pip install flaml

# %%
from flaml import AutoML
automl = AutoML()
automl.fit(X_train, y_train, task="classification")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-61004ccf48ac> in <module>
# ----> 1 from flaml import AutoML
#       2 automl = AutoML()
#       3 automl.fit(X_train, y_train, task="classification")
#
# ~\AppData\Roaming\Python\Python38\site-packages\flaml\__init__.py in <module>
#       1 from flaml.searcher import CFO, BlendSearch, FLOW2, BlendSearchTuner
# ----> 2 from flaml.automl import AutoML, logger_formatter
#       3 from flaml.onlineml.autovw import AutoVW
#       4 from flaml.version import __version__
#       5 import logging
#
# ~\AppData\Roaming\Python\Python38\site-packages\flaml\automl.py in <module>
#      21 import logging
#      22
# ---> 23 from .ml import (
#      24     compute_estimator,
#      25     train_estimator,
#
# ~\AppData\Roaming\Python\Python38\site-packages\flaml\ml.py in <module>
#       7 import numpy as np
#       8 import pandas as pd
# ----> 9 from sklearn.metrics import (
#      10     mean_squared_error,
#      11     r2_score,
#
# ImportError: cannot import name 'mean_absolute_percentage_error' from 'sklearn.metrics' (C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\sklearn\metrics\__init__.py)

# %%
python -c "import sklearn; sklearn.show_versions()"
# Out:
#   File "<ipython-input-31-f1e9ceca1d5c>", line 1
#     python -c "import sklearn; sklearn.show_versions()"
#               ^
# SyntaxError: invalid syntax

# %%
import sklearn

# %%
sklearn.show_versions()
# Out:
# System:
#     python: 3.8.11 (default, Aug  6 2021, 09:57:55) [MSC v.1916 64 bit (AMD64)]
# executable: C:\Users\lu_xi\anaconda3\envs\mma\python.exe
#    machine: Windows-10-10.0.19043-SP0
#
# Python dependencies:
#           pip: 21.0.1
#    setuptools: 52.0.0.post20210125
#       sklearn: 0.23.2
#         numpy: 1.19.5
#         scipy: 1.5.4
#        Cython: 0.29.14
#        pandas: 1.3.2
#    matplotlib: 3.4.3
#        joblib: 1.0.1
# threadpoolctl: 2.2.0
#
# Built with OpenMP: True

# %%
pip install -U scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (1.0)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: joblib>=0.11 in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: numpy>=1.14.6 in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (from scikit-learn) (1.19.5)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (from scikit-learn) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (from scikit-learn) (2.2.0)

# %%
from sklearn.utils import check_arrays
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = check_arrays(y_true, y_pred)

    ## Note: does not handle mix 1d representation
    #if _is_1d(y_true): 
    #    y_true, y_pred = _check_1d_array(y_true, y_pred)

    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-30-27afb8a72d07> in <module>
# ----> 1 from sklearn.utils import check_arrays
#       2 def mean_absolute_percentage_error(y_true, y_pred):
#       3     y_true, y_pred = check_arrays(y_true, y_pred)
#       4
#       5     ## Note: does not handle mix 1d representation
#
# ImportError: cannot import name 'check_arrays' from 'sklearn.utils' (C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\sklearn\utils\__init__.py)

# %%
! pip install numpy scipy cython
! pip install --verbose --no-build-isolation --editable .
# Out:
# Requirement already satisfied: numpy in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (1.19.5)
# Requirement already satisfied: scipy in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (1.5.4)
# Requirement already satisfied: cython in c:\users\lu_xi\anaconda3\envs\mma\lib\site-packages (0.29.14)
# Using pip 21.0.1 from C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip (python 3.8)
# ERROR: File "setup.py" not found. Directory cannot be installed in editable mode: c:\Users\lu_xi\OneDrive\GitRepos\Islington\Study\823_Financial_Analytics
# Non-user install because site-packages writeable
# Created temporary directory: C:\Users\lu_xi\AppData\Local\Temp\pip-ephem-wheel-cache-24xw1fyu
# Created temporary directory: C:\Users\lu_xi\AppData\Local\Temp\pip-req-tracker-4vtf3qob
# Initialized build tracking at C:\Users\lu_xi\AppData\Local\Temp\pip-req-tracker-4vtf3qob
# Created build tracker: C:\Users\lu_xi\AppData\Local\Temp\pip-req-tracker-4vtf3qob
# Entered build tracker: C:\Users\lu_xi\AppData\Local\Temp\pip-req-tracker-4vtf3qob
# Created temporary directory: C:\Users\lu_xi\AppData\Local\Temp\pip-install-cov8snr9
# Exception information:
# Traceback (most recent call last):
#   File "C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip\_internal\cli\base_command.py", line 189, in _main
#     status = self.run(options, args)
#   File "C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip\_internal\cli\req_command.py", line 178, in wrapper
#     return func(self, options, args)
#   File "C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip\_internal\commands\install.py", line 287, in run
#     reqs = self.get_requirements(args, options, finder, session)
#   File "C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip\_internal\cli\req_command.py", line 348, in get_requirements
#     req_to_add = install_req_from_editable(
#   File "C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip\_internal\req\constructors.py", line 212, in install_req_from_editable
#     parts = parse_req_from_editable(editable_req)
#   File "C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip\_internal\req\constructors.py", line 183, in parse_req_from_editable
#     name, url, extras_override = parse_editable(editable_req)
#   File "C:\Users\lu_xi\anaconda3\envs\mma\lib\site-packages\pip\_internal\req\constructors.py", line 96, in parse_editable
#     raise InstallationError(msg)
# pip._internal.exceptions.InstallationError: File "setup.py" not found. Directory cannot be installed in editable mode: c:\Users\lu_xi\OneDrive\GitRepos\Islington\Study\823_Financial_Analytics
# Removed build tracker: 'C:\\Users\\lu_xi\\AppData\\Local\\Temp\\pip-req-tracker-4vtf3qob'
